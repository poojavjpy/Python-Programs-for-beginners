# %% [markdown]
# ### ***Write a Python program to calculate Simple Interest and Compound Interest.***

# %%
# Program to calculate Simple Interest and Compound Interest

principal = float(input("Enter Principal Amount: "))
rate = float(input("Enter Rate of Interest: "))
time = float(input("Enter Time in years: "))

# Simple Interest
simple_interest = (principal * rate * time) / 100

# Compound Interest
amount = principal * (1 + rate / 100) ** time
compound_interest = amount - principal

print("Simple Interest =", simple_interest)
print("Compound Interest =", compound_interest)
# Out:
# Enter Principal Amount: 15000
# Enter Rate of Interest: 10
# Enter Time in years: 8
# Simple Interest = 12000.0
# Compound Interest = 17153.832150000024

# %% [markdown]
# ### ***And Write a Python program to calculate the area of a circle and rectangle.***

# %%
import math

# Circle
radius = float(input("Enter radius of circle: "))

circle_area = math.pi * radius ** 2
circle_perimeter = 2 * math.pi * radius

print(f"Area of Circle = {circle_area:.2f}")


# Rectangle
length = float(input("Enter length of rectangle: "))
breadth = float(input("Enter breadth of rectangle: "))

rectangle_area = length * breadth
rectangle_perimeter = 2 * (length + breadth)

print(f"Area of Rectangle = {rectangle_area:.2f}")
# Out:
# Enter radius of circle: 4
# Area of Circle = 50.27
# Enter length of rectangle: 5
# Enter breadth of rectangle: 6
# Area of Rectangle = 30.00
